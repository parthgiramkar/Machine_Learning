# %%
import pandas as pd    #HTTP (HyperText Transfer Protocol) is a protocol used for communication between web browsers and web servers.
import requests           #to make HTTP requests to fetch data from APIs.

# %%
url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMzZiMjAxOWU3NWFmZGVlZWNmZjgzZGM0MTNjYmIxMyIsIm5iZiI6MTczNzQ2NTI1My4zNDIwMDAyLCJzdWIiOiI2NzhmOWRhNTAxYTcxYWNhNTRmMDhhYTgiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.Vph5mrhxnX7Es_Y3Lx63vos4kdbcPbLdD93gB9MqCkI"
}

response = requests.get(url, headers=headers)           #sends an HTTP GET request to the TMDb API for authentication.

print(response.json())
# Out:
# {'success': True}

# %%
url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page=1"          #fetch the top rated movies from the page1

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMzZiMjAxOWU3NWFmZGVlZWNmZjgzZGM0MTNjYmIxMyIsIm5iZiI6MTczNzQ2NTI1My4zNDIwMDAyLCJzdWIiOiI2NzhmOWRhNTAxYTcxYWNhNTRmMDhhYTgiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.Vph5mrhxnX7Es_Y3Lx63vos4kdbcPbLdD93gB9MqCkI"
}

response = requests.get(url, headers=headers)

response.json()          #as its dictionary we convert it to list into which they are list in which present are  dictionaries
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 49.3266,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.707,
#    'vote_count': 28115},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 45.5023,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.687,
#    'vote_count': 21317},
#   {'adult': False,
#    'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#    'genre_ids': [18, 80],
#    'id': 240,
#    'original_language': 'en',
#    'original_title': 'The Godfather Part II',
#    'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#    'popularity': 22.0334,
#    'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#    'release_date': '1974-12-20',
#    'title': 'The Godfather Part II',
#    'video': False,
#    'vote_average': 8.57,
#    'vote_count': 12884},
#   {'adult': False,
#    'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#    'genre_ids': [18, 36, 10752],
#    'id': 424,
#    'original_language': 'en',
#    'original_title': "Schindler's List",
#    'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#    'popularity': 24.2569,
#    'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#    'release_date': '1993-12-15',
#    'title': "Schindler's List",
#    'video': False,
#    'vote_average': 8.564,
#    'vote_count': 16350},
#   {'adult': False,
#    'backdrop_path': '/bxgTSUenZDHNFerQ1whRKplrMKF.jpg',
#    'genre_ids': [18],
#    'id': 389,
#    'original_language': 'en',
#    'original_title': '12 Angry Men',
#    'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#    'popularity': 18.3842,
#    'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg',
#    'release_date': '1957-04-10',
#    'title': '12 Angry Men',
#    'video': False,
#    'vote_average': 8.547,
#    'vote_count': 9067},
#   {'adult': False,
#    'backdrop_path': '/6oaL4DP75yABrd5EbC4H2zq5ghc.jpg',
#    'genre_ids': [16, 10751, 14],
#    'id': 129,
#    'original_language': 'ja',
#    'original_title': '千と千尋の神隠し',
#    'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#    'popularity': 32.6152,
#    'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#    'release_date': '2001-07-20',
#    'title': 'Spirited Away',
#    'video': False,
#    'vote_average': 8.538,
#    'vote_count': 17023},
#   {'adult': False,
#    'backdrop_path': '/oOv2oUXcAaNXakRqUPxYq5lJURz.jpg',
#    'genre_ids': [18, 28, 80, 53],
#    'id': 155,
#    'original_language': 'en',
#    'original_title': 'The Dark Knight',
#    'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#    'popularity': 34.3612,
#    'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#    'release_date': '2008-07-16',
#    'title': 'The Dark Knight',
#    'video': False,
#    'vote_average': 8.519,
#    'vote_count': 33698},
#   {'adult': False,
#    'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 19404,
#    'original_language': 'hi',
#    'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#    'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#    'popularity': 8.0495,
#    'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg',
#    'release_date': '1995-10-20',
#    'title': 'Dilwale Dulhania Le Jayenge',
#    'video': False,
#    'vote_average': 8.516,
#    'vote_count': 4480},
#   {'adult': False,
#    'backdrop_path': '/vxJ08SvwomfKbpboCWynC3uqUg4.jpg',
#    'genre_ids': [14, 18, 80],
#    'id': 497,
#    'original_language': 'en',
#    'original_title': 'The Green Mile',
#    'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#    'popularity': 20.8367,
#    'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#    'release_date': '1999-12-10',
#    'title': 'The Green Mile',
#    'video': False,
#    'vote_average': 8.505,
#    'vote_count': 17993},
#   {'adult': False,
#    'backdrop_path': '/hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg',
#    'genre_ids': [35, 53, 18],
#    'id': 496243,
#    'original_language': 'ko',
#    'original_title': '기생충',
#    'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#    'popularity': 33.4211,
#    'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#    'release_date': '2019-05-30',
#    'title': 'Parasite',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 18921},
#   {'adult': False,
#    'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#    'genre_ids': [53, 80],
#    'id': 680,
#    'original_language': 'en',
#    'original_title': 'Pulp Fiction',
#    'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#    'popularity': 23.668,
#    'poster_path': '/vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg',
#    'release_date': '1994-09-10',
#    'title': 'Pulp Fiction',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 28550},
#   {'adult': False,
#    'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#    'genre_ids': [16, 10749, 18],
#    'id': 372058,
#    'original_language': 'ja',
#    'original_title': '君の名は。',
#    'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#    'popularity': 24.6151,
#    'poster_path': '/8GJsy7w7frGquw1cy9jasOGNNI1.jpg',
#    'release_date': '2016-08-26',
#    'title': 'Your Name.',
#    'video': False,
#    'vote_average': 8.485,
#    'vote_count': 11708},
#   {'adult': False,
#    'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#    'genre_ids': [12, 14, 28],
#    'id': 122,
#    'original_language': 'en',
#    'original_title': 'The Lord of the Rings: The Return of the King',
#    'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#    'popularity': 23.7105,
#    'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#    'release_date': '2003-12-17',
#    'title': 'The Lord of the Rings: The Return of the King',
#    'video': False,
#    'vote_average': 8.483,
#    'vote_count': 24956},
#   {'adult': False,
#    'backdrop_path': '/ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg',
#    'genre_ids': [35, 18, 10749],
#    'id': 13,
#    'original_language': 'en',
#    'original_title': 'Forrest Gump',
#    'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#    'popularity': 24.5042,
#    'poster_path': '/arw2vcBveWOVZr6pxd9XTd1TdQa.jpg',
#    'release_date': '1994-06-23',
#    'title': 'Forrest Gump',
#    'video': False,
#    'vote_average': 8.468,
#    'vote_count': 28083},
#   {'adult': False,
#    'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#    'genre_ids': [37],
#    'id': 429,
#    'original_language': 'it',
#    'original_title': 'Il buono, il brutto, il cattivo',
#    'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#    'popularity': 30.0099,
#    'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#    'release_date': '1966-12-22',
#    'title': 'The Good, the Bad and the Ugly',
#    'video': False,
#    'vote_average': 8.5,
#    'vote_count': 8930},
#   {'adult': False,
#    'backdrop_path': '/7TF4p86ZafnxFuNqWdhpHXFO244.jpg',
#    'genre_ids': [18, 80],
#    'id': 769,
#    'original_language': 'en',
#    'original_title': 'GoodFellas',
#    'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#    'popularity': 19.2311,
#    'poster_path': '/aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg',
#    'release_date': '1990-09-12',
#    'title': 'GoodFellas',
#    'video': False,
#    'vote_average': 8.456,
#    'vote_count': 13276},
#   {'adult': False,
#    'backdrop_path': '/sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg',
#    'genre_ids': [28, 18],
#    'id': 346,
#    'original_language': 'ja',
#    'original_title': '七人の侍',
#    'overview': "A samurai answers a village's request for protection after he falls on hard times. The town needs protection from bandits, so the samurai gathers six others to help him teach the people how to defend themselves, and the villagers provide the soldiers with food.",
#    'popularity': 6.624,
#    'poster_path': '/8OKmBV5BUFzmozIC3pPWKHy17kx.jpg',
#    'release_date': '1954-04-26',
#    'title': 'Seven Samurai',
#    'video': False,
#    'vote_average': 8.457,
#    'vote_count': 3860},
#   {'adult': False,
#    'backdrop_path': '/8sNiAPPYU14PUepFNeSNGUTiHW.jpg',
#    'genre_ids': [12, 18, 878],
#    'id': 157336,
#    'original_language': 'en',
#    'original_title': 'Interstellar',
#    'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#    'popularity': 46.3566,
#    'poster_path': '/gEU2QniE6E77NI6lCU6MxlNBvIx.jpg',
#    'release_date': '2014-11-05',
#    'title': 'Interstellar',
#    'video': False,
#    'vote_average': 8.454,
#    'vote_count': 36921},
#   {'adult': False,
#    'backdrop_path': '/tDFvXn4tane9lUvFAFAUkMylwSr.jpg',
#    'genre_ids': [16, 18, 10752],
#    'id': 12477,
#    'original_language': 'ja',
#    'original_title': '火垂るの墓',
#    'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#    'popularity': 0.0147,
#    'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#    'release_date': '1988-04-16',
#    'title': 'Grave of the Fireflies',
#    'video': False,
#    'vote_average': 8.452,
#    'vote_count': 5838},
#   {'adult': False,
#    'backdrop_path': '/gavyCu1UaTaTNPsVaGXT6pe5u24.jpg',
#    'genre_ids': [35, 18],
#    'id': 637,
#    'original_language': 'it',
#    'original_title': 'La vita è bella',
#    'overview': 'A touching story of an Italian book seller of Jewish ancestry who lives in his own little fairy tale. His creative and happy life would come to an abrupt halt when his entire family is deported to a concentration camp during World War II. While locked up he tries to convince his son that the whole thing is just a game.',
#    'popularity': 12.4613,
#    'poster_path': '/74hLDKjD5aGYOotO6esUVaeISa2.jpg',
#    'release_date': '1997-12-20',
#    'title': 'Life Is Beautiful',
#    'video': False,
#    'vote_average': 8.448,
#    'vote_count': 13299}],
#  'total_pages': 504,
#  'total_results': 10080}

# %%
response.json()['results']       #so now in complete json format of desired , so extracting the result key which contains the deatil

# in TMDb API response, the "results" key contains a list of dictionaries where in each contains movie with details like id, title, vote_average etc
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 49.3266,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.707,
#   'vote_count': 28115},
#  {'adult': False,
#   'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 45.5023,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.687,
#   'vote_count': 21317},
#  {'adult': False,
#   'backdrop_path': '/kGzFbGhp99zva6oZODW5atUtnqi.jpg',
#   'genre_ids': [18, 80],
#   'id': 240,
#   'original_language': 'en',
#   'original_title': 'The Godfather Part II',
#   'overview': 'In the continuing saga of the Corleone crime family, a young Vito Corleone grows up in Sicily and in 1910s New York. In the 1950s, Michael Corleone attempts to expand the family business into Las Vegas, Hollywood and Cuba.',
#   'popularity': 22.0334,
#   'poster_path': '/hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg',
#   'release_date': '1974-12-20',
#   'title': 'The Godfather Part II',
#   'video': False,
#   'vote_average': 8.57,
#   'vote_count': 12884},
#  {'adult': False,
#   'backdrop_path': '/zb6fM1CX41D9rF9hdgclu0peUmy.jpg',
#   'genre_ids': [18, 36, 10752],
#   'id': 424,
#   'original_language': 'en',
#   'original_title': "Schindler's List",
#   'overview': 'The true story of how businessman Oskar Schindler saved over a thousand Jewish lives from the Nazis while they worked as slaves in his factory during World War II.',
#   'popularity': 24.2569,
#   'poster_path': '/sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg',
#   'release_date': '1993-12-15',
#   'title': "Schindler's List",
#   'video': False,
#   'vote_average': 8.564,
#   'vote_count': 16350},
#  {'adult': False,
#   'backdrop_path': '/bxgTSUenZDHNFerQ1whRKplrMKF.jpg',
#   'genre_ids': [18],
#   'id': 389,
#   'original_language': 'en',
#   'original_title': '12 Angry Men',
#   'overview': "The defense and the prosecution have rested and the jury is filing into the jury room to decide if a young Spanish-American is guilty or innocent of murdering his father. What begins as an open and shut case soon becomes a mini-drama of each of the jurors' prejudices and preconceptions about the trial, the accused, and each other.",
#   'popularity': 18.3842,
#   'poster_path': '/ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg',
#   'release_date': '1957-04-10',
#   'title': '12 Angry Men',
#   'video': False,
#   'vote_average': 8.547,
#   'vote_count': 9067},
#  {'adult': False,
#   'backdrop_path': '/6oaL4DP75yABrd5EbC4H2zq5ghc.jpg',
#   'genre_ids': [16, 10751, 14],
#   'id': 129,
#   'original_language': 'ja',
#   'original_title': '千と千尋の神隠し',
#   'overview': 'A young girl, Chihiro, becomes trapped in a strange new world of spirits. When her parents undergo a mysterious transformation, she must call upon the courage she never knew she had to free her family.',
#   'popularity': 32.6152,
#   'poster_path': '/39wmItIWsg5sZMyRUHLkWBcuVCM.jpg',
#   'release_date': '2001-07-20',
#   'title': 'Spirited Away',
#   'video': False,
#   'vote_average': 8.538,
#   'vote_count': 17023},
#  {'adult': False,
#   'backdrop_path': '/oOv2oUXcAaNXakRqUPxYq5lJURz.jpg',
#   'genre_ids': [18, 28, 80, 53],
#   'id': 155,
#   'original_language': 'en',
#   'original_title': 'The Dark Knight',
#   'overview': 'Batman raises the stakes in his war on crime. With the help of Lt. Jim Gordon and District Attorney Harvey Dent, Batman sets out to dismantle the remaining criminal organizations that plague the streets. The partnership proves to be effective, but they soon find themselves prey to a reign of chaos unleashed by a rising criminal mastermind known to the terrified citizens of Gotham as the Joker.',
#   'popularity': 34.3612,
#   'poster_path': '/qJ2tW6WMUDux911r6m7haRef0WH.jpg',
#   'release_date': '2008-07-16',
#   'title': 'The Dark Knight',
#   'video': False,
#   'vote_average': 8.519,
#   'vote_count': 33698},
#  {'adult': False,
#   'backdrop_path': '/90ez6ArvpO8bvpyIngBuwXOqJm5.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 19404,
#   'original_language': 'hi',
#   'original_title': 'दिलवाले दुल्हनिया ले जायेंगे',
#   'overview': 'Raj is a rich, carefree, happy-go-lucky second generation NRI. Simran is the daughter of Chaudhary Baldev Singh, who in spite of being an NRI is very strict about adherence to Indian values. Simran has left for India to be married to her childhood fiancé. Raj leaves for India with a mission at his hands, to claim his lady love under the noses of her whole family. Thus begins a saga.',
#   'popularity': 8.0495,
#   'poster_path': '/lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg',
#   'release_date': '1995-10-20',
#   'title': 'Dilwale Dulhania Le Jayenge',
#   'video': False,
#   'vote_average': 8.516,
#   'vote_count': 4480},
#  {'adult': False,
#   'backdrop_path': '/vxJ08SvwomfKbpboCWynC3uqUg4.jpg',
#   'genre_ids': [14, 18, 80],
#   'id': 497,
#   'original_language': 'en',
#   'original_title': 'The Green Mile',
#   'overview': "A supernatural tale set on death row in a Southern prison, where gentle giant John Coffey possesses the mysterious power to heal people's ailments. When the cell block's head guard, Paul Edgecomb, recognizes Coffey's miraculous gift, he tries desperately to help stave off the condemned man's execution.",
#   'popularity': 20.8367,
#   'poster_path': '/8VG8fDNiy50H4FedGwdSVUPoaJe.jpg',
#   'release_date': '1999-12-10',
#   'title': 'The Green Mile',
#   'video': False,
#   'vote_average': 8.505,
#   'vote_count': 17993},
#  {'adult': False,
#   'backdrop_path': '/hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg',
#   'genre_ids': [35, 53, 18],
#   'id': 496243,
#   'original_language': 'ko',
#   'original_title': '기생충',
#   'overview': "All unemployed, Ki-taek's family takes peculiar interest in the wealthy and glamorous Parks for their livelihood until they get entangled in an unexpected incident.",
#   'popularity': 33.4211,
#   'poster_path': '/7IiTTgloJzvGI1TAYymCfbfl3vT.jpg',
#   'release_date': '2019-05-30',
#   'title': 'Parasite',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 18921},
#  {'adult': False,
#   'backdrop_path': '/suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg',
#   'genre_ids': [53, 80],
#   'id': 680,
#   'original_language': 'en',
#   'original_title': 'Pulp Fiction',
#   'overview': "A burger-loving hit man, his philosophical partner, a drug-addled gangster's moll and a washed-up boxer converge in this sprawling, comedic crime caper. Their adventures unfurl in three stories that ingeniously trip back and forth in time.",
#   'popularity': 23.668,
#   'poster_path': '/vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg',
#   'release_date': '1994-09-10',
#   'title': 'Pulp Fiction',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 28550},
#  {'adult': False,
#   'backdrop_path': '/8x9iKH8kWA0zdkgNdpAew7OstYe.jpg',
#   'genre_ids': [16, 10749, 18],
#   'id': 372058,
#   'original_language': 'ja',
#   'original_title': '君の名は。',
#   'overview': 'High schoolers Mitsuha and Taki are complete strangers living separate lives. But one night, they suddenly switch places. Mitsuha wakes up in Taki’s body, and he in hers. This bizarre occurrence continues to happen randomly, and the two must adjust their lives around each other.',
#   'popularity': 24.6151,
#   'poster_path': '/8GJsy7w7frGquw1cy9jasOGNNI1.jpg',
#   'release_date': '2016-08-26',
#   'title': 'Your Name.',
#   'video': False,
#   'vote_average': 8.485,
#   'vote_count': 11708},
#  {'adult': False,
#   'backdrop_path': '/2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg',
#   'genre_ids': [12, 14, 28],
#   'id': 122,
#   'original_language': 'en',
#   'original_title': 'The Lord of the Rings: The Return of the King',
#   'overview': 'As armies mass for a final battle that will decide the fate of the world--and powerful, ancient forces of Light and Dark compete to determine the outcome--one member of the Fellowship of the Ring is revealed as the noble heir to the throne of the Kings of Men. Yet, the sole hope for triumph over evil lies with a brave hobbit, Frodo, who, accompanied by his loyal friend Sam and the hideous, wretched Gollum, ventures deep into the very dark heart of Mordor on his seemingly impossible quest to destroy the Ring of Power.\u200b',
#   'popularity': 23.7105,
#   'poster_path': '/rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg',
#   'release_date': '2003-12-17',
#   'title': 'The Lord of the Rings: The Return of the King',
#   'video': False,
#   'vote_average': 8.483,
#   'vote_count': 24956},
#  {'adult': False,
#   'backdrop_path': '/ghgfzbEV7kbpbi1O8eIILKVXEA8.jpg',
#   'genre_ids': [35, 18, 10749],
#   'id': 13,
#   'original_language': 'en',
#   'original_title': 'Forrest Gump',
#   'overview': 'A man with a low IQ has accomplished great things in his life and been present during significant historic events—in each case, far exceeding what anyone imagined he could do. But despite all he has achieved, his one true love eludes him.',
#   'popularity': 24.5042,
#   'poster_path': '/arw2vcBveWOVZr6pxd9XTd1TdQa.jpg',
#   'release_date': '1994-06-23',
#   'title': 'Forrest Gump',
#   'video': False,
#   'vote_average': 8.468,
#   'vote_count': 28083},
#  {'adult': False,
#   'backdrop_path': '/x4biAVdPVCghBlsVIzB6NmbghIz.jpg',
#   'genre_ids': [37],
#   'id': 429,
#   'original_language': 'it',
#   'original_title': 'Il buono, il brutto, il cattivo',
#   'overview': 'While the Civil War rages on between the Union and the Confederacy, three men – a quiet loner, a ruthless hitman, and a Mexican bandit – comb the American Southwest in search of a strongbox containing $200,000 in stolen gold.',
#   'popularity': 30.0099,
#   'poster_path': '/bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg',
#   'release_date': '1966-12-22',
#   'title': 'The Good, the Bad and the Ugly',
#   'video': False,
#   'vote_average': 8.5,
#   'vote_count': 8930},
#  {'adult': False,
#   'backdrop_path': '/7TF4p86ZafnxFuNqWdhpHXFO244.jpg',
#   'genre_ids': [18, 80],
#   'id': 769,
#   'original_language': 'en',
#   'original_title': 'GoodFellas',
#   'overview': 'The true story of Henry Hill, a half-Irish, half-Sicilian Brooklyn kid who is adopted by neighbourhood gangsters at an early age and climbs the ranks of a Mafia family under the guidance of Jimmy Conway.',
#   'popularity': 19.2311,
#   'poster_path': '/aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg',
#   'release_date': '1990-09-12',
#   'title': 'GoodFellas',
#   'video': False,
#   'vote_average': 8.456,
#   'vote_count': 13276},
#  {'adult': False,
#   'backdrop_path': '/sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg',
#   'genre_ids': [28, 18],
#   'id': 346,
#   'original_language': 'ja',
#   'original_title': '七人の侍',
#   'overview': "A samurai answers a village's request for protection after he falls on hard times. The town needs protection from bandits, so the samurai gathers six others to help him teach the people how to defend themselves, and the villagers provide the soldiers with food.",
#   'popularity': 6.624,
#   'poster_path': '/8OKmBV5BUFzmozIC3pPWKHy17kx.jpg',
#   'release_date': '1954-04-26',
#   'title': 'Seven Samurai',
#   'video': False,
#   'vote_average': 8.457,
#   'vote_count': 3860},
#  {'adult': False,
#   'backdrop_path': '/8sNiAPPYU14PUepFNeSNGUTiHW.jpg',
#   'genre_ids': [12, 18, 878],
#   'id': 157336,
#   'original_language': 'en',
#   'original_title': 'Interstellar',
#   'overview': 'The adventures of a group of explorers who make use of a newly discovered wormhole to surpass the limitations on human space travel and conquer the vast distances involved in an interstellar voyage.',
#   'popularity': 46.3566,
#   'poster_path': '/gEU2QniE6E77NI6lCU6MxlNBvIx.jpg',
#   'release_date': '2014-11-05',
#   'title': 'Interstellar',
#   'video': False,
#   'vote_average': 8.454,
#   'vote_count': 36921},
#  {'adult': False,
#   'backdrop_path': '/tDFvXn4tane9lUvFAFAUkMylwSr.jpg',
#   'genre_ids': [16, 18, 10752],
#   'id': 12477,
#   'original_language': 'ja',
#   'original_title': '火垂るの墓',
#   'overview': 'In the final months of World War II, 14-year-old Seita and his sister Setsuko are orphaned when their mother is killed during an air raid in Kobe, Japan. After a falling out with their aunt, they move into an abandoned bomb shelter. With no surviving relatives and their emergency rations depleted, Seita and Setsuko struggle to survive.',
#   'popularity': 0.0147,
#   'poster_path': '/k9tv1rXZbOhH7eiCk378x61kNQ1.jpg',
#   'release_date': '1988-04-16',
#   'title': 'Grave of the Fireflies',
#   'video': False,
#   'vote_average': 8.452,
#   'vote_count': 5838},
#  {'adult': False,
#   'backdrop_path': '/gavyCu1UaTaTNPsVaGXT6pe5u24.jpg',
#   'genre_ids': [35, 18],
#   'id': 637,
#   'original_language': 'it',
#   'original_title': 'La vita è bella',
#   'overview': 'A touching story of an Italian book seller of Jewish ancestry who lives in his own little fairy tale. His creative and happy life would come to an abrupt halt when his entire family is deported to a concentration camp during World War II. While locked up he tries to convince his son that the whole thing is just a game.',
#   'popularity': 12.4613,
#   'poster_path': '/74hLDKjD5aGYOotO6esUVaeISa2.jpg',
#   'release_date': '1997-12-20',
#   'title': 'Life Is Beautiful',
#   'video': False,
#   'vote_average': 8.448,
#   'vote_count': 13299}]

# %%
pd.DataFrame(response.json()['results'])         #in a good readable manner
# Out:
#     adult                     backdrop_path         genre_ids       id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]      278
# 1   False  /tmU7GeKVybMWFButWEGl2M4GeiP.jpg          [18, 80]      238
# 2   False  /kGzFbGhp99zva6oZODW5atUtnqi.jpg          [18, 80]      240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]      424
# 4   False  /bxgTSUenZDHNFerQ1whRKplrMKF.jpg              [18]      389
# 5   False  /6oaL4DP75yABrd5EbC4H2zq5ghc.jpg   [16, 10751, 14]      129
# 6   False  /90ez6ArvpO8bvpyIngBuwXOqJm5.jpg   [35, 18, 10749]    19404
# 7   False  /oOv2oUXcAaNXakRqUPxYq5lJURz.jpg  [18, 28, 80, 53]      155
# 8   False  /vxJ08SvwomfKbpboCWynC3uqUg4.jpg      [14, 18, 80]      497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]   496243
# 10  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg          [53, 80]      680
# 11  False  /8x9iKH8kWA0zdkgNdpAew7OstYe.jpg   [16, 10749, 18]   372058
# 12  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]      122
# 13  False  /deUWVEgNh2IGjShyymZhaYP40ye.jpg      [28, 12, 53]  1356039
# 14  False  /mzfx54nfDPTUXZOG48u4LaEheDy.jpg   [35, 18, 10749]       13
# 15  False  /x4biAVdPVCghBlsVIzB6NmbghIz.jpg              [37]      429
# 16  False  /sJNNMCc6B7KZIY3LH3JMYJJNH5j.jpg          [28, 18]      346
# 17  False  /7TF4p86ZafnxFuNqWdhpHXFO244.jpg          [18, 80]      769
# 18  False   /8sNiAPPYU14PUepFNeSNGUTiHW.jpg     [12, 18, 878]   157336
# 19  False  /tDFvXn4tane9lUvFAFAUkMylwSr.jpg   [16, 18, 10752]    12477
#
#    original_language                                 original_title  \
# 0                 en                       The Shawshank Redemption
# 1                 en                                  The Godfather
# 2                 en                          The Godfather Part II
# 3                 en                               Schindler's List
# 4                 en                                   12 Angry Men
# 5                 ja                                       千と千尋の神隠し
# 6                 hi                   दिलवाले दुल्हनिया ले जायेंगे
# 7                 en                                The Dark Knight
# 8                 en                                 The Green Mile
# 9                 ko                                            기생충
# 10                en                                   Pulp Fiction
# 11                ja                                          君の名は。
# 12                en  The Lord of the Rings: The Return of the King
# 13                es                                   Contraataque
# 14                en                                   Forrest Gump
# 15                it                Il buono, il brutto, il cattivo
# 16                ja                                           七人の侍
# 17                en                                     GoodFellas
# 18                en                                   Interstellar
# 19                ja                                          火垂るの墓
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...       5.466
# 1   Spanning the years 1945 to 1955, a chronicle o...       5.092
# 2   In the continuing saga of the Corleone crime f...       5.093
# 3   The true story of how businessman Oskar Schind...       5.295
# 4   The defense and the prosecution have rested an...       3.941
# 5   A young girl, Chihiro, becomes trapped in a st...       4.673
# 6   Raj is a rich, carefree, happy-go-lucky second...       3.530
# 7   Batman raises the stakes in his war on crime. ...       5.291
# 8   A supernatural tale set on death row in a Sout...       5.221
# 9   All unemployed, Ki-taek's family takes peculia...       4.745
# 10  A burger-loving hit man, his philosophical par...       5.252
# 11  High schoolers Mitsuha and Taki are complete s...       3.844
# 12  As armies mass for a final battle that will de...       5.220
# 13  When a hostage rescue mission creates a new en...       6.400
# 14  A man with a low IQ has accomplished great thi...       4.988
# 15  While the Civil War rages on between the Union...       4.913
# 16  A samurai answers a village's request for prot...       4.106
# 17  The true story of Henry Hill, a half-Irish, ha...       5.208
# 18  The adventures of a group of explorers who mak...       6.223
# 19  In the final months of World War II, 14-year-o...       0.004
#
#                          poster_path release_date  \
# 0   /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23
# 1   /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14
# 2   /hek3koDUyRQk7FIhPXsa6mT2Zc3.jpg   1974-12-20
# 3   /sF1U4EUQS8YHUYjNl3pMGNIQyr0.jpg   1993-12-15
# 4   /ow3wq89wM8qd5X7hWKxiRfsFf9C.jpg   1957-04-10
# 5   /39wmItIWsg5sZMyRUHLkWBcuVCM.jpg   2001-07-20
# 6   /lfRkUr7DYdHldAqi3PwdQGBRBPM.jpg   1995-10-20
# 7   /qJ2tW6WMUDux911r6m7haRef0WH.jpg   2008-07-16
# 8   /8VG8fDNiy50H4FedGwdSVUPoaJe.jpg   1999-12-10
# 9   /7IiTTgloJzvGI1TAYymCfbfl3vT.jpg   2019-05-30
# 10  /vQWk5YBFWF4bZaofAbv0tShwBvQ.jpg   1994-09-10
# 11  /q719jXXEzOoYaps6babgKnONONX.jpg   2016-08-26
# 12  /rCzpDGLbOoPwLjy3OAm5NUPOTrC.jpg   2003-12-17
# 13  /lI2uFlSEkwXKljqiry7coaJ6wIS.jpg   2025-02-27
# 14  /arw2vcBveWOVZr6pxd9XTd1TdQa.jpg   1994-06-23
# 15  /bX2xnavhMYjWDoZp1VM6VnU1xwe.jpg   1966-12-22
# 16  /8OKmBV5BUFzmozIC3pPWKHy17kx.jpg   1954-04-26
# 17  /aKuFiU82s5ISJpGZp7YkIr3kCUd.jpg   1990-09-12
# 18  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg   2014-11-05
# 19  /k9tv1rXZbOhH7eiCk378x61kNQ1.jpg   1988-04-16
#
#                                             title  video  vote_average  \
# 0                        The Shawshank Redemption  False         8.700
# 1                                   The Godfather  False         8.689
# 2                           The Godfather Part II  False         8.568
# 3                                Schindler's List  False         8.567
# 4                                    12 Angry Men  False         8.500
# 5                                   Spirited Away  False         8.500
# 6                     Dilwale Dulhania Le Jayenge  False         8.500
# 7                                 The Dark Knight  False         8.519
# 8                                  The Green Mile  False         8.505
# 9                                        Parasite  False         8.501
# 10                                   Pulp Fiction  False         8.500
# 11                                     Your Name.  False         8.500
# 12  The Lord of the Rings: The Return of the King  False         8.481
# 13                                  Counterattack  False         8.492
# 14                                   Forrest Gump  False         8.468
# 15                 The Good, the Bad and the Ugly  False         8.500
# 16                                  Seven Samurai  False         8.458
# 17                                     GoodFellas  False         8.457
# 18                                   Interstellar  False         8.500
# 19                         Grave of the Fireflies  False         8.451
#
#     vote_count
# 0        27919
# 1        21172
# 2        12786
# 3        16240
# 4         8971
# 5        16922
# 6         4468
# 7        33564
# 8        17909
# 9        18810
# 10       28445
# 11       11653
# 12       24811
# 13         488
# 14       27974
# 15        8867
# 16        3826
# 17       13190
# 18       36740
# 19        5785

# %%
#selecting the required columns i.e 9 , so total movies - 10043*9(dimn)   in 2d array form as we to put in table not series of
pd.DataFrame(response.json()['results'])[['id','original_language','original_title','overview','popularity','release_date','title','vote_average','vote_count']]
# Out:
#         id original_language                                 original_title  \
# 0      278                en                       The Shawshank Redemption
# 1      238                en                                  The Godfather
# 2      240                en                          The Godfather Part II
# 3      424                en                               Schindler's List
# 4      389                en                                   12 Angry Men
# 5      129                ja                                       千と千尋の神隠し
# 6      155                en                                The Dark Knight
# 7    19404                hi                   दिलवाले दुल्हनिया ले जायेंगे
# 8      497                en                                 The Green Mile
# 9   496243                ko                                            기생충
# 10     680                en                                   Pulp Fiction
# 11  372058                ja                                          君の名は。
# 12     122                en  The Lord of the Rings: The Return of the King
# 13      13                en                                   Forrest Gump
# 14     429                it                Il buono, il brutto, il cattivo
# 15     769                en                                     GoodFellas
# 16     346                ja                                           七人の侍
# 17  157336                en                                   Interstellar
# 18   12477                ja                                          火垂るの墓
# 19     637                it                                La vita è bella
#
#                                              overview  popularity  \
# 0   Imprisoned in the 1940s for the double murder ...     49.3266
# 1   Spanning the years 1945 to 1955, a chronicle o...     45.5023
# 2   In the continuing saga of the Corleone crime f...     22.0334
# 3   The true story of how businessman Oskar Schind...     24.2569
# 4   The defense and the prosecution have rested an...     18.3842
# 5   A young girl, Chihiro, becomes trapped in a st...     32.6152
# 6   Batman raises the stakes in his war on crime. ...     34.3612
# 7   Raj is a rich, carefree, happy-go-lucky second...      8.0495
# 8   A supernatural tale set on death row in a Sout...     20.8367
# 9   All unemployed, Ki-taek's family takes peculia...     33.4211
# 10  A burger-loving hit man, his philosophical par...     23.6680
# 11  High schoolers Mitsuha and Taki are complete s...     24.6151
# 12  As armies mass for a final battle that will de...     23.7105
# 13  A man with a low IQ has accomplished great thi...     24.5042
# 14  While the Civil War rages on between the Union...     30.0099
# 15  The true story of Henry Hill, a half-Irish, ha...     19.2311
# 16  A samurai answers a village's request for prot...      6.6240
# 17  The adventures of a group of explorers who mak...     46.3566
# 18  In the final months of World War II, 14-year-o...      0.0147
# 19  A touching story of an Italian book seller of ...     12.4613
#
#    release_date                                          title  vote_average  \
# 0    1994-09-23                       The Shawshank Redemption         8.707
# 1    1972-03-14                                  The Godfather         8.687
# 2    1974-12-20                          The Godfather Part II         8.570
# 3    1993-12-15                               Schindler's List         8.564
# 4    1957-04-10                                   12 Angry Men         8.547
# 5    2001-07-20                                  Spirited Away         8.538
# 6    2008-07-16                                The Dark Knight         8.519
# 7    1995-10-20                    Dilwale Dulhania Le Jayenge         8.516
# 8    1999-12-10                                 The Green Mile         8.505
# 9    2019-05-30                                       Parasite         8.500
# 10   1994-09-10                                   Pulp Fiction         8.500
# 11   2016-08-26                                     Your Name.         8.485
# 12   2003-12-17  The Lord of the Rings: The Return of the King         8.483
# 13   1994-06-23                                   Forrest Gump         8.468
# 14   1966-12-22                 The Good, the Bad and the Ugly         8.500
# 15   1990-09-12                                     GoodFellas         8.456
# 16   1954-04-26                                  Seven Samurai         8.457
# 17   2014-11-05                                   Interstellar         8.454
# 18   1988-04-16                         Grave of the Fireflies         8.452
# 19   1997-12-20                              Life Is Beautiful         8.448
#
#     vote_count
# 0        28115
# 1        21317
# 2        12884
# 3        16350
# 4         9067
# 5        17023
# 6        33698
# 7         4480
# 8        17993
# 9        18921
# 10       28550
# 11       11708
# 12       24956
# 13       28083
# 14        8930
# 15       13276
# 16        3860
# 17       36921
# 18        5838
# 19       13299

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','original_language','original_title','overview','popularity','release_date','title','vote_average','vote_count']]

# %%
temp_df.head()   #starting five i.e the top five
# Out:
#     id original_language            original_title  \
# 0  278                en  The Shawshank Redemption
# 1  238                en             The Godfather
# 2  240                en     The Godfather Part II
# 3  424                en          Schindler's List
# 4  389                en              12 Angry Men
#
#                                             overview  popularity release_date  \
# 0  Imprisoned in the 1940s for the double murder ...     49.3266   1994-09-23
# 1  Spanning the years 1945 to 1955, a chronicle o...     45.5023   1972-03-14
# 2  In the continuing saga of the Corleone crime f...     22.0334   1974-12-20
# 3  The true story of how businessman Oskar Schind...     24.2569   1993-12-15
# 4  The defense and the prosecution have rested an...     18.3842   1957-04-10
#
#                       title  vote_average  vote_count
# 0  The Shawshank Redemption         8.707       28115
# 1             The Godfather         8.687       21317
# 2     The Godfather Part II         8.570       12884
# 3          Schindler's List         8.564       16350
# 4              12 Angry Men         8.547        9067

# %%
df = pd.DataFrame()             #put the empty

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,503) :                                  #running the loop for all pages
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)       #Dynamically updates the url by inserting the page number using .format(i)

    headers = {
          "accept": "application/json",
          "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMzZiMjAxOWU3NWFmZGVlZWNmZjgzZGM0MTNjYmIxMyIsIm5iZiI6MTczNzQ2NTI1My4zNDIwMDAyLCJzdWIiOiI2NzhmOWRhNTAxYTcxYWNhNTRmMDhhYTgiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.Vph5mrhxnX7Es_Y3Lx63vos4kdbcPbLdD93gB9MqCkI"
    }

    response = requests.get(url, headers=headers)

# %%
for i in range(1, 503):
    url = "https://api.themoviedb.org/3/movie/top_rated?language=en-US&page={}".format(i)

    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlMzZiMjAxOWU3NWFmZGVlZWNmZjgzZGM0MTNjYmIxMyIsIm5iZiI6MTczNzQ2NTI1My4zNDIwMDAyLCJzdWIiOiI2NzhmOWRhNTAxYTcxYWNhNTRmMDhhYTgiLCJzY29wZXMiOlsiYXBpX3JlYWQiXSwidmVyc2lvbiI6MX0.Vph5mrhxnX7Es_Y3Lx63vos4kdbcPbLdD93gB9MqCkI"
    }

    response = requests.get(url, headers=headers)

    # Check if the response is successful(http code=200) and contains the 'results' key
    if response.status_code == 200 and 'results' in response.json():
        temp_df = pd.DataFrame(response.json()['results'])[['id', 'original_language', 'original_title', 'overview', 'popularity', 'release_date', 'title', 'vote_average', 'vote_count']]
        df = pd.concat([df, temp_df], ignore_index=True)                # as after the loop the index should be 20 not 1-19 return

# %%
df
# Out:
#           id original_language                             original_title  \
# 0        278                en                   The Shawshank Redemption
# 1        238                en                              The Godfather
# 2        240                en                      The Godfather Part II
# 3        424                en                           Schindler's List
# 4        389                en                               12 Angry Men
# ...      ...               ...                                        ...
# 9995  218043                en                                Left Behind
# 9996   10073                en                                 Date Movie
# 9997    3602                en  I'll Always Know What You Did Last Summer
# 9998   23988                en                               Stan Helsing
# 9999  375798                fr                                    Brice 3
#
#                                                overview  popularity  \
# 0     Imprisoned in the 1940s for the double murder ...       5.466
# 1     Spanning the years 1945 to 1955, a chronicle o...       5.092
# 2     In the continuing saga of the Corleone crime f...       5.093
# 3     The true story of how businessman Oskar Schind...       5.295
# 4     The defense and the prosecution have rested an...       3.941
# ...                                                 ...         ...
# 9995  A small group of survivors are left behind aft...       5.324
# 9996  Spoof of romantic comedies which focuses on a ...       3.531
# 9997  Several teenagers in a small-town in Colorado ...       3.568
# 9998  A spoof on many horror movie series. Ending hi...       3.532
# 9999  Brice is back. The world has changed, but not ...       3.830
#
#      release_date                                      title  vote_average  \
# 0      1994-09-23                   The Shawshank Redemption         8.700
# 1      1972-03-14                              The Godfather         8.689
# 2      1974-12-20                      The Godfather Part II         8.568
# 3      1993-12-15                           Schindler's List         8.567
# 4      1957-04-10                               12 Angry Men         8.500
# ...           ...                                        ...           ...
# 9995   2014-10-03                                Left Behind         4.300
# 9996   2006-02-17                                 Date Movie         4.200
# 9997   2006-06-24  I'll Always Know What You Did Last Summer         4.200
# 9998   2009-10-23                               Stan Helsing         4.200
# 9999   2016-10-19                                    Brice 3         4.217
#
#       vote_count
# 0          27919
# 1          21172
# 2          12786
# 3          16240
# 4           8971
# ...          ...
# 9995        1315
# 9996         991
# 9997         394
# 9998         479
# 9999         621
#
# [10000 rows x 9 columns]

# %%
df.shape
# Out:
# (10000, 9)

# %%
df.to_csv("movies_data.csv", index=False)
#Saves the df DataFrame into a CSV file named "movies_data.csv"
#index=False ensures that the row index is not included in the CSV file

# %%
from google.colab import files
files.download("movies_data.csv")

# %%
import pandas as pd
df = pd.read_csv('Data.csv')

# %% [markdown]
# HOW BIG IS THE DATA

# %%
df.shape
# Out:
# (10, 4)

# %% [markdown]
# HOW BIG DOES THE DATA LOOK

# %%
df.head()         # the top 5rows means it gives you the preview of the data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes

# %%
df.sample(5)          #for 5 random rows of the data
# Out:
#    Country   Age   Salary Purchased
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 4  Germany  40.0      NaN       Yes
# 2  Germany  30.0  54000.0        No

# %%
#for the data type of the data of cols and how space it acquired
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    10 non-null     object
#  1   Age        9 non-null      float64
#  2   Salary     9 non-null      float64
#  3   Purchased  10 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 452.0+ bytes

# %% [markdown]
# ```
# ARE THERE ANY MISSING VALUES
# ```

# %%
df.isnull().sum()          # no.of missing values
# Out:
# Country      0
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %% [markdown]
# HOW DOES THE DATA LOOK MATHEMATICALLY

# %%
df.describe()         # insights only on the numerical column
# Out:
#              Age        Salary
# count   9.000000      9.000000
# mean   38.777778  63777.777778
# std     7.693793  12265.579662
# min    27.000000  48000.000000
# 25%    35.000000  54000.000000
# 50%    38.000000  61000.000000
# 75%    44.000000  72000.000000
# max    50.000000  83000.000000

# %% [markdown]
# ARE THERE ANY DUPLICATES VALUE??

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.corr(numeric_only=True)
# Out:
#              Age    Salary
# Age     1.000000  0.982495
# Salary  0.982495  1.000000

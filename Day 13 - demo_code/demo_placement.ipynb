# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
df = pd.read_csv('/content/placement.csv')

# %%
df= df.iloc[ : , 1 : ]                                  #it preprocessed the data by removing col named-unnnanmed try it to find that prev col

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 3)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df ["cgpa"] ,df ["iq"])

# %%
#in colour form

plt.scatter(df ["cgpa"] ,df ["iq"] , c=df["placement"])

# %%
#linear regression - EDA
#feature scaling
X= df.iloc[ : ,0:2]
y=df.iloc[ : ,-1]

# %%
X
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
#1-D tensor
# Out:
# (100,)

# %%
#Train test split
# cgpa and iq i.e - X are independent variables as no link to each other and y dependent variable we have to give
# test_size=0.1-- 10% of 100 to testing and later to training
from sklearn.model_selection import train_test_split
train_test_split( X , y ,test_size=0.1)
# Out:
# [    cgpa     iq
#  74   6.7  154.0
#  85   5.8  166.0
#  54   6.4  141.0
#  89   4.9  151.0
#  39   4.6  146.0
#  ..   ...    ...
#  82   6.5   37.0
#  32   7.0  139.0
#  20   6.6  120.0
#  55   7.8  114.0
#  84   5.7  169.0
#
#  [90 rows x 2 columns],
#      cgpa     iq
#  79   6.5   90.0
#  25   5.0   91.0
#  83   7.5  130.0
#  11   6.9  138.0
#  21   7.1  151.0
#  80   4.9  196.0
#  42   7.6   89.0
#  24   4.7  121.0
#  36   5.7  140.0
#  57   6.5  130.0,
#  74    1
#  85    1
#  54    1
#  89    0
#  39    0
#       ..
#  82    1
#  32    1
#  20    1
#  55    1
#  84    0
#  Name: placement, Length: 90, dtype: int64,
#  79    1
#  25    0
#  83    1
#  11    1
#  21    1
#  80    0
#  42    1
#  24    0
#  36    0
#  57    1
#  Name: placement, dtype: int64]

# %%
X_train, X_test ,y_train ,y_test = train_test_split( X , y ,test_size=0.1)

# %%
X_train
# Out:
#     cgpa     iq
# 72   7.3  116.0
# 47   5.2  161.0
# 97   6.7  182.0
# 38   6.5  160.0
# 84   5.7  169.0
# ..   ...    ...
# 92   5.2  110.0
# 28   5.2   90.0
# 70   6.3  127.0
# 99   6.2  113.0
# 8    6.1  156.0
#
# [90 rows x 2 columns]

# %%
X_test
# Out:
#     cgpa     iq
# 13   6.4  116.0
# 43   6.8  141.0
# 17   3.3  183.0
# 76   4.9  155.0
# 33   6.0  149.0
# 94   4.7   52.0
# 68   4.0   75.0
# 91   7.5  158.0
# 79   6.5   90.0
# 37   8.1  149.0

# %%
y_test
# Out:
# 13    1
# 43    1
# 17    0
# 76    0
# 33    0
# 94    0
# 68    0
# 91    1
# 79    1
# 37    1
# Name: placement, dtype: int64

# %%
#scaling

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()               #created obj scaler

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[ 1.1798945 , -0.18183572],
#        [-0.74086399,  0.95114068],
#        [ 0.63110636,  1.479863  ],
#        [ 0.44817698,  0.92596343],
#        [-0.28354054,  1.1525587 ],
#        [-0.00914647,  0.01958231],
#        [ 0.72257105, -0.00559495],
#        [-2.29576372,  2.76390291],
#        [ 0.44817698, -2.17083873],
#        [ 0.99696512, -1.89388894],
#        [ 0.2652476 , -0.50914001],
#        [ 0.90550043, -0.28254473],
#        [-0.92379337, -0.13148121],
#        [ 1.91161202,  1.07702695],
#        [ 1.45428857,  0.12029132],
#        [ 0.08231822, -1.06303958],
#        [-0.83232868,  1.32879948],
#        [ 0.08231822,  0.22100033],
#        [-1.10672275,  1.00149519],
#        [ 0.35671229,  0.44759561],
#        [ 1.1798945 , -0.93715332],
#        [-1.01525806, -0.0811267 ],
#        [ 0.44817698,  0.17064583],
#        [-0.92379337, -1.51623014],
#        [ 1.82014733, -1.11339409],
#        [ 2.27747078, -0.0811267 ],
#        [-1.28965213,  0.57348188],
#        [ 1.27135919,  0.22100033],
#        [ 1.1798945 ,  0.3468866 ],
#        [ 0.90550043,  0.39724111],
#        [ 0.08231822, -0.50914001],
#        [-1.19818744, -0.05594945],
#        [-1.5640462 ,  1.93305356],
#        [-0.55793461,  0.29653209],
#        [ 0.72257105, -0.8364443 ],
#        [ 0.81403574,  0.39724111],
#        [-1.10672275, -0.28254473],
#        [-0.55793461,  0.39724111],
#        [ 0.90550043,  1.9078763 ],
#        [-0.92379337, -0.81126705],
#        [ 1.63721795, -0.23219022],
#        [-0.55793461, -0.408431  ],
#        [-1.92990496, -0.35807649],
#        [ 1.36282388, -1.56658465],
#        [-1.01525806, -1.56658465],
#        [ 1.45428857, -0.86162156],
#        [-0.00914647, -0.53431726],
#        [-0.19207585,  0.47277287],
#        [ 0.72257105, -0.28254473],
#        [-0.28354054,  0.22100033],
#        [-0.74086399,  2.53730763],
#        [-1.47258151,  0.64901364],
#        [ 0.08231822, -1.46587563],
#        [-0.83232868, -1.44069838],
#        [ 0.90550043, -1.49105289],
#        [-1.01525806,  1.83234454],
#        [-1.10672275,  0.44759561],
#        [ 0.2652476 ,  0.12029132],
#        [-0.55793461, -0.23219022],
#        [-0.28354054,  0.49795012],
#        [-1.01525806,  0.27135484],
#        [ 1.1798945 , -1.84353443],
#        [ 0.53964167,  0.37206385],
#        [ 0.53964167, -0.0811267 ],
#        [-0.19207585,  1.07702695],
#        [-0.83232868,  0.12029132],
#        [ 0.99696512,  0.69936815],
#        [-1.83844027, -0.58467177],
#        [-1.47258151, -2.04495246],
#        [-0.6493993 , -0.05594945],
#        [-1.10672275,  1.1525587 ],
#        [-0.74086399,  0.22100033],
#        [-0.28354054,  0.42241836],
#        [-0.6493993 , -0.23219022],
#        [-0.00914647, -1.9694207 ],
#        [-0.00914647, -1.44069838],
#        [ 0.81403574,  0.37206385],
#        [-1.01525806,  0.69936815],
#        [ 0.81403574, -0.68538078],
#        [-0.10061116, -0.43360825],
#        [ 2.0945414 ,  1.12738145],
#        [-1.19818744, -0.91197606],
#        [ 0.90550043,  1.30362222],
#        [ 0.63110636,  0.77489991],
#        [ 1.36282388,  0.17064583],
#        [-0.74086399, -0.33289924],
#        [-0.74086399, -0.8364443 ],
#        [ 0.2652476 ,  0.09511407],
#        [ 0.17378291, -0.25736748],
#        [ 0.08231822,  0.82525441]])

# %%
from sklearn.linear_model import LogisticRegression
clf= LogisticRegression()               #created obj of clf

# %%
#Model training of trained model
clf.fit(X_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LogisticRegression was fitted without feature names
#   warnings.warn(

# %%
y_test
# Out:
# 13    1
# 43    1
# 17    0
# 76    0
# 33    0
# 94    0
# 68    0
# 91    1
# 79    1
# 37    1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test , y_pred)
# Out:
# 0.5

# %%
from mlxtend.plotting import plot_decision_regions
plot_decision_regions(X_train , y_train.values , clf=clf , legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf, open('model.pkl' , 'wb') )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-18f779556c37> in <cell line: 1>()
# ----> 1 pickle.dump(clf, open('model.pkl' , 'wb') )
#
# NameError: name 'pickle' is not defined

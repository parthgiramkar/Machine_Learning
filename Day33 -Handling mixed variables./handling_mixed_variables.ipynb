# %% [markdown]
# IMPORT THE NECESSARY LIBRARIES

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')

# %%
df                  # here number represents the person  travelling with how many people
# Out:
#     Cabin            Ticket number  Survived
# 0     NaN         A/5 21171      5         0
# 1     C85          PC 17599      3         1
# 2     NaN  STON/O2. 3101282      6         1
# 3    C123            113803      3         1
# 4     NaN            373450      A         0
# ..    ...               ...    ...       ...
# 886   NaN            211536      3         0
# 887   B42            112053      3         1
# 888   NaN        W./C. 6607      1         0
# 889  C148            111369      2         1
# 890   NaN            370376      3         0
#
# [891 rows x 4 columns]

# %%
df.dtypes
# Out:
# Cabin       object
# Ticket      object
# number      object
# Survived     int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Cabin       687
# Ticket        0
# number        0
# Survived      0
# dtype: int64

# %%
df['number'].unique()    #NumPy sets the data type to object as it is string
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %% [markdown]
# PEFORMING NECESSARY OPERATIONS ON THE MIXED_VAR_COLN'S

# %%
# ok so when the column contains both the numerical and categorical data then
# so now extracting the numerical part                     coerce - if values cannot be conbvertd to number then store itasNan,downcast
df['number_numerical'] = pd.to_numeric(df['number']  , errors='coerce' , downcast='integer')
df
# to save memory by using int types8,16
# Out:
#     Cabin            Ticket number  Survived  number_numerical
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
# [891 rows x 5 columns]

# %%
# now extracting the categorical part
# from number_numeric ifits null means its char so set it from from the orign col ,else its nan
df['number_categorical'] = np.where(df['number_numerical'].isnull() , df['number'] , np.nan)
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                    A
# ..                 ...
# 886                NaN
# ...

# %%
# so now cabin and ticket has mixed_values
df['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df['Ticket'].unique()
# Out:
# array(['A/5 21171', 'PC 17599', 'STON/O2. 3101282', '113803', '373450',
#        '330877', '17463', '349909', '347742', '237736', 'PP 9549',
#        '113783', 'A/5. 2151', '347082', '350406', '248706', '382652',
#        '244373', '345763', '2649', '239865', '248698', '330923', '113788',
#        '347077', '2631', '19950', '330959', '349216', 'PC 17601',
#        'PC 17569', '335677', 'C.A. 24579', 'PC 17604', '113789', '2677',
#        'A./5. 2152', '345764', '2651', '7546', '11668', '349253',
#        'SC/Paris 2123', '330958', 'S.C./A.4. 23567', '370371', '14311',
#        '2662', '349237', '3101295', 'A/4. 39886', 'PC 17572', '2926',
#        '113509', '19947', 'C.A. 31026', '2697', 'C.A. 34651', 'CA 2144',
#        '2669', '113572', '36973', '347088', 'PC 17605', '2661',
#        'C.A. 29395', 'S.P. 3464', '3101281', '315151', 'C.A. 33111',
#        'S.O.C. 14879', '2680', '1601', '348123', '349208', '374746',
# ...

# %%
#thenumeric partmethodwould notworkhere as they were seperatedvalues
# but herevlaues are aplhaumeric
df['Cabin_categorical']=df['Cabin'].str[0]   #aschar isinfirstindexonly

# %%
df['Cabin_numerical']=df['Cabin'].str.extract('(\d+)')   #extract_thenumerical_part from string
df                           # \d+means oneormoredigit
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical Cabin_categorical Cabin_numerical
# 0                  NaN               NaN             NaN
# 1                  NaN                 C              85
# ...

# %%
df['Cabin_categorical'].value_counts()   #how many_values_appears_inthe_column
# Out:
# Cabin_categorical
# C    59
# B    47
# D    33
# E    32
# A    15
# F    13
# G     4
# T     1
# Name: count, dtype: int64

# %%
df['Cabin_categorical'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin_categorical'>

# %%
# now ticket contains no.of symbols,char,numbers aplhanumericstrings withsymbols

df['ticket_categorical']=df['Ticket'].str.extract('^([A-Za-z0-9./]+)')

# ^startofthestring [..]A character class thenallcharnumber + Match one or more of the allowed characters

# %%
# df['ticket_numerical']=df['Ticket'].str.extract('(\d+)')  notwork_asweneed to extract the last part of string
# with 	A/5 21171 it will extract 5 also witit so -

df['ticket_numerical']=df['Ticket'].str.extract('(\d+)$')
df
# Out:
#     Cabin            Ticket number  Survived  number_numerical  \
# 0     NaN         A/5 21171      5         0               5.0
# 1     C85          PC 17599      3         1               3.0
# 2     NaN  STON/O2. 3101282      6         1               6.0
# 3    C123            113803      3         1               3.0
# 4     NaN            373450      A         0               NaN
# ..    ...               ...    ...       ...               ...
# 886   NaN            211536      3         0               3.0
# 887   B42            112053      3         1               3.0
# 888   NaN        W./C. 6607      1         0               1.0
# 889  C148            111369      2         1               2.0
# 890   NaN            370376      3         0               3.0
#
#     number_categorical Cabin_categorical Cabin_numerical ticket_categorical  \
# 0                  NaN               NaN             NaN                A/5
# ...
